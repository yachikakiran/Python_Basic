# %%
"""
1. What is the difference between interpreted and compiled languages?
ans. Interpreted languages execute code line by line at runtime, without needing a separate compilation step. Examples: Python, JavaScript.
Compiled languages convert the entire code into machine code before execution, improving performance. Examples: C, C++.

2. What is exception handling in Python?
ans. It is a mechanism to handle runtime errors using try, except, finally, and else blocks to prevent program crashes.

3. What is the purpose of the finally block in exception handling?
ans. The finally block is executed regardless of whether an exception occurs, typically used for cleanup operations like 
closing files or releasing resources.

4. What is logging in Python?
ans. The logging module provides a way to track events in a program, useful for debugging, monitoring, and error tracking.

5. What is the significance of the __del__ method in Python?
ans. It is a destructor method that is called when an object is about to be destroyed, used to free resources like file handles or network connections.

6. What is the difference between import and from ... import in Python?
ans. import module imports the entire module, requiring module.function().
from module import function imports specific functions or variables, allowing direct use without module prefix.

7. How can you handle multiple exceptions in Python?
ans. Use multiple except blocks for different exceptions or use except (Exception1, Exception2) as e: to handle multiple exceptions in one block.

8. What is the purpose of the with statement when handling files in Python?
ans. It ensures proper file closure after use, even if an exception occurs. Example:
with open("file.txt", "r") as file:
    data = file.read()
    
9. What is the difference between multithreading and multiprocessing?
ans. Multithreading: Uses multiple threads within a single process, sharing memory, good for I/O-bound tasks.
Multiprocessing: Uses multiple processes, each with its own memory space, better for CPU-bound tasks.

10. What are the advantages of using logging in a program?
ans. * Provides detailed error tracking
* Helps in debugging and maintenance
* Allows different logging levels (INFO, WARNING, ERROR)
* Supports saving logs to files

11. What is memory management in Python?
ans. Python manages memory using reference counting and garbage collection to free unused memory automatically.

12. What are the basic steps involved in exception handling in Python?
ans. * Use try block for risky code.
* Use except block to handle exceptions.
* Use else block for code that runs if no exceptions occur.
* Use finally block for cleanup operations.

13. Why is memory management important in Python?
ans. Prevents memory leaks
Ensures efficient resource utilization
Optimizes program performance

14. What is the role of try and except in exception handling?
ans. try contains code that might raise an exception.
except catches and handles specific exceptions.

15. How does Python's garbage collection system work?
ans. Uses reference counting to track object usage.
Uses generational garbage collection to remove cyclic references.

16. What is the purpose of the else block in exception handling?
ans. if no exceptions occur inside try. Example:
try:
    result = 10 / 2
except ZeroDivisionError:
    print("Cannot divide by zero")
else:
    print("Division successful")
    
17. What are the common logging levels in Python?
ans. DEBUG – Detailed information for debugging
INFO – General system information
WARNING – Non-critical issues
ERROR – Serious problems
CRITICAL – Very severe errors

18. What is the difference between os.fork() and multiprocessing in Python?
ans. os.fork(): Creates a child process in UNIX-based systems.
multiprocessing: Portable across platforms and safer for complex process management.

19. What is the importance of closing a file in Python?
ans. Prevents memory leaks
Ensures data is properly written
Releases system resources

20. What is the difference between file.read() and file.readline() in Python?
ans. file.read(): Reads the entire file.
file.readline(): Reads one line at a time.

21. What is the logging module in Python used for? 
ans. Provides a standardized way to log events and errors in a program.

22. What is the os module in Python used for in file handling?
ans. Used for file operations like creating, deleting, and renaming files, as well as navigating directories.

23. What are the challenges associated with memory management in Python?\
ans. Circular references affecting garbage collection
High memory usage due to dynamic typing
Performance overhead due to automatic memory management

24. How do you raise an exception manually in Python?
ans. Use the raise statement:
raise ValueError("Invalid input")

25. Why is it important to use multithreading in certain applications?
ans. Improves performance for I/O-bound tasks
Allows concurrent execution
Efficiently utilizes CPU resources in certain cases
"""

# %%
 
#1. How can you open a file for writing in Python and write a string to it"""
with open("output.txt", "w") as file:
    file.write("Hello, world!")

#2. Write a Python program to read the contents of a file and print each line
with open("input.txt", "r") as file:
    for line in file:
        print(line.strip())


#3. How would you handle a case where the file doesn't exist while tryito open it for reading 
try:
    with open("nonexistent.txt", "r") as file:
        content = file.read()
except FileNotFoundError:
    print("Error: The file does not exist.")

#4. Write a Python script that reads from one file and writes its content to another file
with open("source.txt", "r") as src, open("destination.txt", "w") as dest:
    dest.write(src.read())
#5. How would you catch and handle division by zero error in Python
try:
    result = 10 / 0
except ZeroDivisionError:
    print("Error: Cannot divide by zero.")

#6. Write a Python program that logs an error message to a log file when a division by zero exception occurs
import logging

logging.basicConfig(filename="errors.log", level=logging.ERROR)

try:
    result = 10 / 0
except ZeroDivisionError as e:
    logging.error("Division by zero error occurred: %s", e)

#7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module

import logging

logging.basicConfig(level=logging.DEBUG)

logging.info("This is an info message.")
logging.warning("This is a warning.")
logging.error("This is an error.")

#8. Write a program to handle a file opening error using exception handling 
try:
    with open("file.txt", "r") as file:
        print(file.read())
except FileNotFoundError:
    print("File not found. Please check the filename.")

#9. How can you read a file line by line and store its content in a list in Python 
with open("data.txt", "r") as file:
    lines = [line.strip() for line in file]
print(lines)

#10. How can you append data to an existing file in Python
with open("file.txt", "a") as file:
    file.write("\nAdditional content")

#11. Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist
try:
    data = {"name": "Alice"}
    print(data["age"])
except KeyError:
    print("Key not found in dictionary.")

#12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions
try:
    num = int("abc")
    result = 10 / 0
except ValueError:
    print("Invalid number format.")
except ZeroDivisionError:
    print("Cannot divide by zero.")

#13. How would you check if a file exists before attempting to read it in Python
import os

if os.path.exists("file.txt"):
    with open("file.txt", "r") as file:
        print(file.read())
else:
    print("File does not exist.")

#14. Write a program that uses the logging module to log both informational and error messages 
import logging

logging.basicConfig(filename="app.log", level=logging.INFO)

logging.info("This is an informational message.")
logging.error("This is an error message.")

#15. Write a Python program that prints the content of a file and handles the case when the file is empty
with open("file.txt", "r") as file:
    content = file.read()
    if content:
        print(content)
    else:
        print("File is empty.")

#16. Demonstrate how to use memory profiling to check the memory usage of a small program 
from memory_profiler import profile

@profile
def my_function():
    data = [i for i in range(10000)]
    return sum(data)

my_function()

#17. Write a Python program to create and write a list of numbers to a file, one number per line 
numbers = [1, 2, 3, 4, 5]

with open("numbers.txt", "w") as file:
    for number in numbers:
        file.write(f"{number}\n")

#18. How would you implement a basic logging setup that logs to a file with rotation after 1MB 
import logging
from logging.handlers import RotatingFileHandler

handler = RotatingFileHandler("app.log", maxBytes=1048576, backupCount=3)
logging.basicConfig(handlers=[handler], level=logging.INFO)

logging.info("This is a log message.")

#19. Write a program that handles both IndexError and KeyError using a try-except block
try:
    lst = [1, 2, 3]
    print(lst[5])

    dictionary = {"a": 1}
    print(dictionary["b"])
except IndexError:
    print("Index out of range.")
except KeyError:
    print("Key not found in dictionary.")

#20. How would you open a file and read its contents using a context manager in Python 
with open("file.txt", "r") as file:
    print(file.read())

#21. Write a Python program that reads a file and prints the number of occurrences of a specific word
word_to_count = "Python"

with open("file.txt", "r") as file:
    content = file.read()
    print(f"Occurrences of '{word_to_count}':", content.count(word_to_count))

#22. How can you check if a file is empty before attempting to read its contents
import os

if os.path.exists("file.txt") and os.stat("file.txt").st_size > 0:
    with open("file.txt", "r") as file:
        print(file.read())
else:
    print("File is empty or does not exist.")

#23. Write a Python program that writes to a log file when an error occurs during file handling.
import logging

logging.basicConfig(filename="file_errors.log", level=logging.ERROR)

try:
    with open("nonexistent.txt", "r") as file:
        content = file.read()
except FileNotFoundError as e:
    logging.error("File not found error: %s", e)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 6
#       3     file.write("Hello, world!")
#       5 #2. Write a Python program to read the contents of a file and print each line
# ----> 6 with open("input.txt", "r") as file:
#       7     for line in file:
#       8         print(line.strip())
#
# File C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'input.txt'

# %%
#2. Write a Python program to read the contents of a file and print each line
with open("input.txt", "r") as file:
    for line in file:
        print(line.strip())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 #2. Write a Python program to read the contents of a file and print each line
# ----> 2 with open("input.txt", "r") as file:
#       3     for line in file:
#       4         print(line.strip())
#
# File C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'input.txt'
